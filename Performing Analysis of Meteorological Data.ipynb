# %% [markdown]
# # Project-1 Performing Analysis of Meteorological Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime,timedelta

# %%
df=pd.read_csv('F:/DATA ANALYST/INTERNSHIP/weatherhistory.csv')
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.drop_duplicates()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# 6      2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain
# 7      2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain
# 8      2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain
# 9      2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain
# 10     2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11     2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12     2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13     2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain
# ...

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df['Precip Type'].mode()
# Out:
# 0    rain
# dtype: object

# %%
df['Precip Type'].fillna('rain',inplace=True)

# %%
df.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
# df['Formatted Date']=pd.to_datetime(['Formatted Date'],format='%d/%m/%Y')

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
tmp=['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
       'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
       'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)',
       'Daily Summary']
for i in tmp:
    print(i)
    print(df[i].value_counts())
# Out:
# Formatted Date
# 2010-08-02 03:00:00.000 +0200    2
# 2010-08-02 19:00:00.000 +0200    2
# 2010-08-02 07:00:00.000 +0200    2
# 2010-08-02 08:00:00.000 +0200    2
# 2010-08-02 14:00:00.000 +0200    2
# 2010-08-02 04:00:00.000 +0200    2
# 2010-08-02 17:00:00.000 +0200    2
# 2010-08-02 09:00:00.000 +0200    2
# 2010-08-02 16:00:00.000 +0200    2
# 2010-08-02 12:00:00.000 +0200    2
# 2010-08-02 23:00:00.000 +0200    2
# 2010-08-02 10:00:00.000 +0200    2
# 2010-08-02 18:00:00.000 +0200    2
# 2010-08-02 22:00:00.000 +0200    2
# 2010-08-02 11:00:00.000 +0200    2
# 2010-08-02 00:00:00.000 +0200    2
# 2010-08-02 02:00:00.000 +0200    2
# 2010-08-02 20:00:00.000 +0200    2
# 2010-08-02 13:00:00.000 +0200    2
# 2010-08-02 06:00:00.000 +0200    2
# 2010-08-02 21:00:00.000 +0200    2
# 2010-08-02 05:00:00.000 +0200    2
# 2010-08-02 01:00:00.000 +0200    2
# 2010-08-02 15:00:00.000 +0200    2
# 2011-09-21 05:00:00.000 +0200    1
# 2007-07-06 15:00:00.000 +0200    1
# ...

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df['Formatted Date']=pd.to_datetime(df['Formatted Date'],utc=True)

# %%
df.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                  float64
# Visibility (km)                         float64
# Loud Cover                              float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
(df['Formatted Date'].dt.month).shape
# Out:
# (96453,)

# %%
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], format= '%d/%m/%Y %H.%M.%S')
df.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                  float64
# Visibility (km)                         float64
# Loud Cover                              float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
new_df = pd.DataFrame({"year": df['Formatted Date'].dt.year,
              "month": df['Formatted Date'].dt.month,
              "day": df['Formatted Date'].dt.day,
              "hour": df['Formatted Date'].dt.hour,
              "dayofyear": df['Formatted Date'].dt.dayofyear,
              "week": df['Formatted Date'].dt.week,
              "dayofweek": df['Formatted Date'].dt.dayofweek,
#               "dayofmonth": df['Formatted Date'].dt.month_name,
              "quarter": df['Formatted Date'].dt.quarter
              
             })
new_df.head()
# Out:
#    year  month  day  hour  dayofyear  week  dayofweek  quarter
# 0  2006      3   31    22         90    13          4        1
# 1  2006      3   31    23         90    13          4        1
# 2  2006      4    1     0         91    13          5        2
# 3  2006      4    1     1         91    13          5        2
# 4  2006      4    1     2         91    13          5        2

# %%
df.shape
# Out:
# (96453, 12)

# %%
# (df.join(new_df)).shape

# %%
# df.join(new_df)

# %%
df.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                  float64
# Visibility (km)                         float64
# Loud Cover                              float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
# df=pd.read_csv('weatherhistory.csv',parse_dates=['Formatted Date'],index_col='Formatted Date')
# df.head()

# %%
# df=df['Formatted Date'].dt.month

# %%
# df.head()

# %%
rng=pd.date_range(start='01/04/2006',end='01/05/2016',freq='M')
rng
# Out:
# DatetimeIndex(['2006-01-31', '2006-02-28', '2006-03-31', '2006-04-30',
#                '2006-05-31', '2006-06-30', '2006-07-31', '2006-08-31',
#                '2006-09-30', '2006-10-31',
#                ...
#                '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30',
#                '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31',
#                '2015-11-30', '2015-12-31'],
#               dtype='datetime64[ns]', length=120, freq='M')

# %%
# df['Formatted Date']=pd.date_range(start='01/04/2006',end='01/04/2016',freq='M')

# %%
# df['Formatted Date'].head()

# %%
# df['Formatted']

# %%
h=pd.Period('2017-05-15 23:00:00',freq='M')
h
# Out:
# Period('2017-05', 'M')

# %%
df['Formatted Date']=pd.to_datetime(df['Formatted Date'],format='%d/%m/%Y')

# %%
df.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df['Formatted Date'].asfreq('M')
# Out:
# C:\Users\Manjot singh\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:574: UserWarning: Discarding nonzero nanoseconds in conversion
#   index = _generate_regular_range(start, end, periods, freq)
# Series([], Freq: M, Name: Formatted Date, dtype: datetime64[ns, UTC])

# %%
# df.set_index(['Formatted Date'],inplace=True)

# %%
df.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df['Formatted Date'].asfreq('M')
# Out:
# C:\Users\Manjot singh\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:574: UserWarning: Discarding nonzero nanoseconds in conversion
#   index = _generate_regular_range(start, end, periods, freq)
# Series([], Freq: M, Name: Formatted Date, dtype: datetime64[ns, UTC])

# %%
df['Formatted Date']=pd.to_datetime(df['Formatted Date'],format='%d/%m/%Y')

# %%
df.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
# df.set_index('Formatted Date')

# %%
df['Daily Summary'].nunique()
# Out:
# 214

# %%
df['Summary'].nunique()
# Out:
# 27

# %%
df.asfreq('M',method='pad')
# Out:
# C:\Users\Manjot singh\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:574: UserWarning: Discarding nonzero nanoseconds in conversion
#   index = _generate_regular_range(start, end, periods, freq)
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
df.dtypes
# Out:
# Formatted Date              datetime64[ns, UTC]
# Summary                                  object
# Precip Type                              object
# Temperature (C)                         float64
# Apparent Temperature (C)                float64
# Humidity                                float64
# Wind Speed (km/h)                       float64
# Wind Bearing (degrees)                  float64
# Visibility (km)                         float64
# Loud Cover                              float64
# Pressure (millibars)                    float64
# Daily Summary                            object
# dtype: object

# %%
# df['Formatted Date'].resample('M').head()

# %%
# df=pd.to_datetime(df['Formatted Date'],format='%d/%m/%Y')

# %%
d=df.join(new_df)

# %%
d.head()
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
a=d.groupby('month')

# %%
a

# %%
b=a.get_group(3)
b
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 5089  2006-03-01 00:00:00+00:00       Overcast        snow        -4.894444
# 5090  2006-03-01 01:00:00+00:00       Overcast        snow        -5.483333
# 5091  2006-03-01 02:00:00+00:00       Overcast        snow        -5.461111
# 5092  2006-03-01 03:00:00+00:00       Overcast        snow        -5.433333
# 5093  2006-03-01 04:00:00+00:00       Overcast        snow        -7.038889
# 5094  2006-03-01 05:00:00+00:00  Mostly Cloudy        snow        -7.566667
# 5095  2006-03-01 06:00:00+00:00  Mostly Cloudy        snow        -6.950000
# 5096  2006-03-01 07:00:00+00:00          Clear        snow        -5.966667
# 5097  2006-03-01 08:00:00+00:00          Clear        snow        -4.744444
# ...

# %%
b.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      8184.000000               8184.000000  8184.000000
# mean          6.914976                  5.082583     0.702849
# std           5.460491                  6.638127     0.185740
# min         -10.100000                -15.055556     0.120000
# 25%           2.838889                  0.388889     0.570000
# 50%           7.155556                  4.708333     0.730000
# 75%          10.286111                 10.286111     0.850000
# max          22.822222                 22.822222     1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count        8184.000000             8184.000000      8184.000000      8184.0
# mean           13.415825              186.632698        10.922231         0.0
# std             8.312239              109.915064         3.636478         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
b['Humidity'].mean()
# Out:
# 0.7028494623655912

# %%
# %matplotlib inline
b['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for March 2006-2010')
# Out:
# Text(0.5,1,'Humidity for March 2006-2010')

# %%
b['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for March 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for March 2006-2010')

# %%
c=a.get_group(1)
c
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 2208  2006-01-31 23:00:00+00:00       Overcast        snow        -2.144444
# 2881  2006-01-01 00:00:00+00:00  Mostly Cloudy        rain         1.161111
# 2882  2006-01-01 01:00:00+00:00  Mostly Cloudy        rain         1.666667
# 2883  2006-01-01 02:00:00+00:00       Overcast        rain         1.711111
# 2884  2006-01-01 03:00:00+00:00  Mostly Cloudy        rain         1.183333
# 2885  2006-01-01 04:00:00+00:00  Mostly Cloudy        rain         1.205556
# 2886  2006-01-01 05:00:00+00:00  Mostly Cloudy        rain         2.222222
# 2887  2006-01-01 06:00:00+00:00  Mostly Cloudy        rain         2.072222
# 2888  2006-01-01 07:00:00+00:00  Mostly Cloudy        rain         2.200000
# 2889  2006-01-01 08:00:00+00:00  Mostly Cloudy        rain         2.733333
# 2890  2006-01-01 09:00:00+00:00  Mostly Cloudy        rain         2.788889
# ...

# %%
c['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for January 2006-2010')
# Out:
# Text(0.5,1,'Humidity for January 2006-2010')

# %%
c['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for January 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for January 2006-2010')

# %%
d=a.get_group(5)
d
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 4368  2006-05-31 22:00:00+00:00  Partly Cloudy        rain         7.277778
# 4369  2006-05-31 23:00:00+00:00  Partly Cloudy        rain         7.294444
# 5833  2006-05-01 00:00:00+00:00       Overcast        rain        11.133333
# 5834  2006-05-01 01:00:00+00:00  Mostly Cloudy        rain        11.600000
# 5835  2006-05-01 02:00:00+00:00  Mostly Cloudy        rain        11.088889
# 5836  2006-05-01 03:00:00+00:00  Mostly Cloudy        rain        10.555556
# 5837  2006-05-01 04:00:00+00:00       Overcast        rain        11.066667
# 5838  2006-05-01 05:00:00+00:00       Overcast        rain        11.094444
# 5839  2006-05-01 06:00:00+00:00       Overcast        rain        12.050000
# 5840  2006-05-01 07:00:00+00:00          Clear        rain        12.155556
# 5841  2006-05-01 08:00:00+00:00       Overcast        rain        12.666667
# ...

# %%
d['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for May 2006-2010')
# Out:
# Text(0.5,1,'Humidity for May 2006-2010')

# %%
d['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for May 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for May 2006-2010')

# %%
e=a.get_group(6)
e
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 3624  2006-06-30 22:00:00+00:00  Mostly Cloudy        rain        17.777778
# 3625  2006-06-30 23:00:00+00:00  Mostly Cloudy        rain        16.688889
# 4370  2006-06-01 00:00:00+00:00  Mostly Cloudy        rain        10.527778
# 4371  2006-06-01 01:00:00+00:00          Clear        rain         7.155556
# 4372  2006-06-01 02:00:00+00:00  Partly Cloudy        rain         6.644444
# 4373  2006-06-01 03:00:00+00:00  Partly Cloudy        rain         5.700000
# 4374  2006-06-01 04:00:00+00:00  Partly Cloudy        rain         7.177778
# 4375  2006-06-01 05:00:00+00:00  Partly Cloudy        rain         8.866667
# 4376  2006-06-01 06:00:00+00:00  Mostly Cloudy        rain        11.083333
# 4377  2006-06-01 07:00:00+00:00  Partly Cloudy        rain        12.761111
# 4378  2006-06-01 08:00:00+00:00  Partly Cloudy        rain        15.000000
# ...

# %%
e['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for June 2006-2010')
# Out:
# Text(0.5,1,'Humidity for June 2006-2010')

# %%
e['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for June 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for June 2006-2010')

# %%
f=a.get_group(7)
f
# Out:
#                  Formatted Date                  Summary Precip Type  \
# 720   2006-07-31 22:00:00+00:00            Partly Cloudy        rain
# 721   2006-07-31 23:00:00+00:00                    Clear        rain
# 3626  2006-07-01 00:00:00+00:00            Partly Cloudy        rain
# 3627  2006-07-01 01:00:00+00:00            Partly Cloudy        rain
# 3628  2006-07-01 02:00:00+00:00            Partly Cloudy        rain
# 3629  2006-07-01 03:00:00+00:00            Mostly Cloudy        rain
# 3630  2006-07-01 04:00:00+00:00            Mostly Cloudy        rain
# 3631  2006-07-01 05:00:00+00:00                 Overcast        rain
# 3632  2006-07-01 06:00:00+00:00                 Overcast        rain
# 3633  2006-07-01 07:00:00+00:00                 Overcast        rain
# 3634  2006-07-01 08:00:00+00:00                 Overcast        rain
# 3635  2006-07-01 09:00:00+00:00            Mostly Cloudy        rain
# 3636  2006-07-01 10:00:00+00:00  Humid and Mostly Cloudy        rain
# ...

# %%
f['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for July 2006-2010')
# Out:
# Text(0.5,1,'Humidity for July 2006-2010')

# %%
f['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for July 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for July 2006-2010')

# %%
g=a.get_group(4)
g
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# 5     2006-04-01 03:00:00+00:00  Partly Cloudy        rain         9.222222
# 6     2006-04-01 04:00:00+00:00  Partly Cloudy        rain         7.733333
# 7     2006-04-01 05:00:00+00:00  Partly Cloudy        rain         8.772222
# 8     2006-04-01 06:00:00+00:00  Partly Cloudy        rain        10.822222
# 9     2006-04-01 07:00:00+00:00  Partly Cloudy        rain        13.772222
# 10    2006-04-01 08:00:00+00:00  Partly Cloudy        rain        16.016667
# 11    2006-04-01 09:00:00+00:00  Partly Cloudy        rain        17.144444
# 12    2006-04-01 10:00:00+00:00  Partly Cloudy        rain        17.800000
# ...

# %%
g['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for April 2006-2010')
# Out:
# Text(0.5,1,'Humidity for April 2006-2010')

# %%
g['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for April 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for April 2006-2010')

# %%
h=a.get_group(8)
h
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 722   2006-08-01 00:00:00+00:00  Mostly Cloudy        rain        20.722222
# 723   2006-08-01 01:00:00+00:00  Partly Cloudy        rain        18.794444
# 724   2006-08-01 02:00:00+00:00  Partly Cloudy        rain        17.733333
# 725   2006-08-01 03:00:00+00:00  Partly Cloudy        rain        17.605556
# 726   2006-08-01 04:00:00+00:00  Partly Cloudy        rain        18.733333
# 727   2006-08-01 05:00:00+00:00  Partly Cloudy        rain        22.555556
# 728   2006-08-01 06:00:00+00:00  Partly Cloudy        rain        24.761111
# 729   2006-08-01 07:00:00+00:00  Partly Cloudy        rain        27.172222
# 730   2006-08-01 08:00:00+00:00  Mostly Cloudy        rain        28.911111
# 731   2006-08-01 09:00:00+00:00  Mostly Cloudy        rain        30.955556
# 732   2006-08-01 10:00:00+00:00  Mostly Cloudy        rain        32.172222
# ...

# %%
h['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for August 2006-2010')
# Out:
# Text(0.5,1,'Humidity for August 2006-2010')

# %%
h['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for August 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for August 2006-2010')

# %%
i=a.get_group(9)
i
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 7295  2006-09-30 22:00:00+00:00          Clear        rain        14.261111
# 7296  2006-09-30 23:00:00+00:00          Clear        rain        13.705556
# 8066  2006-09-01 00:00:00+00:00          Clear        rain        10.644444
# 8067  2006-09-01 01:00:00+00:00          Clear        rain        13.266667
# 8068  2006-09-01 02:00:00+00:00  Partly Cloudy        rain        12.222222
# 8069  2006-09-01 03:00:00+00:00  Partly Cloudy        rain        11.672222
# 8070  2006-09-01 04:00:00+00:00  Partly Cloudy        rain        11.138889
# 8071  2006-09-01 05:00:00+00:00  Partly Cloudy        rain        12.155556
# 8072  2006-09-01 06:00:00+00:00  Partly Cloudy        rain        13.772222
# 8073  2006-09-01 07:00:00+00:00          Clear        rain        16.161111
# 8074  2006-09-01 08:00:00+00:00          Clear        rain        17.827778
# ...

# %%
i['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for September 2006-2010')
# Out:
# Text(0.5,1,'Humidity for September 2006-2010')

# %%
i['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for September 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for September 2006-2010')

# %%
j=a.get_group(10)
j
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 6575  2006-10-31 23:00:00+00:00  Mostly Cloudy        rain         1.016667
# 7297  2006-10-01 00:00:00+00:00  Partly Cloudy        rain        13.255556
# 7298  2006-10-01 01:00:00+00:00          Clear        rain        13.177778
# 7299  2006-10-01 02:00:00+00:00          Clear        rain        12.105556
# 7300  2006-10-01 03:00:00+00:00          Clear        rain        12.272222
# 7301  2006-10-01 04:00:00+00:00          Foggy        rain        10.994444
# 7302  2006-10-01 05:00:00+00:00          Foggy        rain        10.972222
# 7303  2006-10-01 06:00:00+00:00          Clear        rain        13.522222
# 7304  2006-10-01 07:00:00+00:00          Clear        rain        17.105556
# 7305  2006-10-01 08:00:00+00:00  Partly Cloudy        rain        20.000000
# 7306  2006-10-01 09:00:00+00:00  Partly Cloudy        rain        22.733333
# ...

# %%
j['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for October 2006-2010')
# Out:
# Text(0.5,1,'Humidity for Octomber 2006-2010')

# %%
j['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for October 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for Octomber 2006-2010')

# %%
k=a.get_group(11)
k
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 1464  2006-11-30 23:00:00+00:00       Overcast        rain         6.572222
# 6576  2006-11-01 00:00:00+00:00  Mostly Cloudy        rain         5.550000
# 6577  2006-11-01 01:00:00+00:00  Mostly Cloudy        snow        -0.116667
# 6578  2006-11-01 02:00:00+00:00  Mostly Cloudy        rain         0.972222
# 6579  2006-11-01 03:00:00+00:00  Mostly Cloudy        rain         0.150000
# 6580  2006-11-01 04:00:00+00:00  Mostly Cloudy        snow        -0.044444
# 6581  2006-11-01 05:00:00+00:00          Clear        rain         0.005556
# 6582  2006-11-01 06:00:00+00:00  Mostly Cloudy        rain         1.011111
# 6583  2006-11-01 07:00:00+00:00       Overcast        rain         2.688889
# 6584  2006-11-01 08:00:00+00:00       Overcast        rain         3.794444
# 6585  2006-11-01 09:00:00+00:00       Overcast        rain         5.894444
# ...

# %%
k['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for November 2006-2010')
# Out:
# Text(0.5,1,'Humidity for November 2006-2010')

# %%
k['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for November 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for November 2006-2010')

# %%
l=a.get_group(12)
l
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 1465  2006-12-01 00:00:00+00:00  Mostly Cloudy        rain         6.627778
# 1466  2006-12-01 01:00:00+00:00       Overcast        rain         6.622222
# 1467  2006-12-01 02:00:00+00:00       Overcast        rain         6.622222
# 1468  2006-12-01 03:00:00+00:00       Overcast        rain         6.150000
# 1469  2006-12-01 04:00:00+00:00       Overcast        rain         6.061111
# 1470  2006-12-01 05:00:00+00:00       Overcast        rain         6.061111
# 1471  2006-12-01 06:00:00+00:00          Foggy        rain         6.100000
# 1472  2006-12-01 07:00:00+00:00          Foggy        rain         6.061111
# 1473  2006-12-01 08:00:00+00:00          Foggy        rain         7.150000
# 1474  2006-12-01 09:00:00+00:00          Foggy        rain         6.227778
# 1475  2006-12-01 10:00:00+00:00          Foggy        rain         7.222222
# ...

# %%
l['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for December 2006-2010')
# Out:
# Text(0.5,1,'Humidity for December 2006-2010')

# %%
l['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for December 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for December 2006-2010')

# %%
n=a.get_group(2)
n
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 2209  2006-02-01 00:00:00+00:00       Overcast        snow        -2.466667
# 2210  2006-02-01 01:00:00+00:00       Overcast        snow        -2.744444
# 2211  2006-02-01 02:00:00+00:00       Overcast        snow        -2.188889
# 2212  2006-02-01 03:00:00+00:00       Overcast        snow        -2.038889
# 2213  2006-02-01 04:00:00+00:00       Overcast        snow        -2.672222
# 2214  2006-02-01 05:00:00+00:00       Overcast        snow        -2.605556
# 2215  2006-02-01 06:00:00+00:00       Overcast        snow        -2.433333
# 2216  2006-02-01 07:00:00+00:00          Foggy        snow        -2.472222
# 2217  2006-02-01 08:00:00+00:00       Overcast        snow        -2.405556
# 2218  2006-02-01 09:00:00+00:00       Overcast        snow        -2.233333
# 2219  2006-02-01 10:00:00+00:00       Overcast        snow        -2.261111
# ...

# %%
n['Humidity'].plot()
plt.ylabel('Humidity')
plt.title('Humidity for Feburary 2006-2010')
# Out:
# Text(0.5,1,'Humidity for Feburary 2006-2010')

# %%
n['Apparent Temperature (C)'].plot()
plt.ylabel('Apparent Temperature (C)')
plt.title('Apparent Temperature (C) for February 2006-2010')
# Out:
# Text(0.5,1,'Apparent Temperature (C) for Feburary 2006-2010')

# %% [markdown]
# # Conclusion:
# There is No change in average humidity. The year 2009 can see an increase in average apparent temperature, then a fall in 2010, then a slight increase in 2011, then a significant drop in 2015, and then an increase in 2016.
